# %%
import json
import cfscrape
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
import datetime
from fake_useragent import UserAgent
useragent = UserAgent()

# %%
useragent.random
# Out:
# 'Mozilla/5.0 (Windows NT 6.2) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/28.0.1464.0 Safari/537.36'

# %%
 yandex_all_id = 59452068765, 1230403863, 135157708122, 13084226257, 122953255163, 1166206684, 1170778562, 1080903330, 1315558370, 1168675286, 1036543306, 5651209305,66697421636,1199923913,1146856379,1752726383,68938452823,1136669337,48923682156,1084785161,106396488794,1169237983,1171367346,1226210503,244588988530,1249340350,1109319679,129281957669,222501363394,95798602015,1808210910,74755559887,39505328349,58618253938,181349390806,222108751806,1004521162,238385424377,1178994977,1809097327,225447574680,1200427674,1142895335,46866695409,1261132791,1780139580,227594122810,57361398610,1360515342,1187228400,205284667443,175499965097,1234696811,1219578186,1243520916,1137893690,1163323346,1395617057,1156420979,1261357675,1137049971,1503884741,147075068049,1173855410,1209203365,1084635139,1357472078,111881168077,1737906159,1159394297,1216178581,1092610521,1218514905

# %%
#yandex_all_id = 1199923913,1146856379,1752726383,68938452823,1136669337,48923682156,1084785161,106396488794,1169237983,1171367346,244588988530,95798602015,1808210910,74755559887,222108751806,1004521162,238385424377,1178994977,1809097327

# %%
#yandex_all_id = 1146856379,1752726383,68938452823,1136669337,48923682156,1084785161,106396488794,1169237983,1171367346

# %%
Data_id = pd.DataFrame((yandex_all_id), columns = ['id'])

# %%
Data_id.head()
# Out:
#              id
# 0   59452068765
# 1    1230403863
# 2  135157708122
# 3   13084226257
# 4  122953255163

# %%
len(Data_id)
# Out:
# 73

# %%
#'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/95.0.4638.54 Safari/537.36'

# %%
estimates_all = pd.DataFrame()

# %%
for i in range(len(Data_id)):
    yandex_id = str(Data_id.iloc[i]['id'])
    date_object = time.strftime("%d.%m.%Y")
    time_object = time.strftime("%H:%M:%S")
    ya = pd.DataFrame({"date": date_object,"time":time_object, "id": yandex_id}, index = [1])
    ya['key'] = 1
    def get_count_star(review_stars):
        star_count = 0
        for review_star in review_stars:
            if '_empty' in review_star.get('class'):
                continue
            elif '_half' in review_star.get('class'):
                star_count = star_count + 0.5
            else:
                star_count = star_count + 1
        return star_count

    def get_session():
        session = requests.Session()
        session.headers = {
            'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
            'sec-ch-ua': '"Google Chrome";v="95", "Chromium";v="95", ";Not A Brand";v="99"',
            'upgrade-insecure-requests': '1',
            #'user-agent': useragent.random,
            'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/95.0.4638.54 Safari/537.36',
            'viewport-width': '1920'
        }
        return cfscrape.create_scraper(sess=session)

    def parsing_data(data_result, r):
        soup = BeautifulSoup(r.text, 'html.parser')
        try:
            reviews = soup.find('div', {"data-chunk": "reviews"})
        except:
            return None
        try:
            summary_rating__main = reviews.find('div', {"class": "business-summary-rating__main-rating"})
        except:
            summary_rating__main = None
        try:
            rank_summary_rating__main = summary_rating__main.find('span',{"class": "business-summary-rating-badge-view__rating"}).text
        except:
            rank_summary_rating__main = None
        try:
            count_summary_rating__main = summary_rating__main.find('div', {
                "class": "business-summary-rating-badge-view__rating-count"}).text
        except:
            count_summary_rating__main = None
        try:
            stars_summary_rating__main = get_count_star(
                summary_rating__main.find('div', {"class": "business-rating-badge-view__stars"}))
        except:
            stars_summary_rating__main = None
        try:
            address = soup.find('meta', {"itemprop": "address"}).get('content')
        except:
            address = None
        data_result['company_info'] = {
            'company_rating': rank_summary_rating__main,
            'company_count_reviews': count_summary_rating__main,
            'company_count_stars': stars_summary_rating__main,
            'company_address': address
        }
        
        return data_result
    
    url = 'https://yandex.ru/maps/org/letay/' + yandex_id
    session = get_session()
    r = session.get(url)
    data_result = {
        'company_info': {}
    }
    data_result
    data_result = parsing_data(data_result, r)
    df = pd.DataFrame(data_result)
    addr = df.loc['company_address']['company_info']
    while addr == None:
        time_new = time.strftime("%H:%M:%S")
        print(time_new,' New query for ',yandex_id)
        time.sleep(300)
        session = get_session()
        r = session.get(url)
        data_result = {
            'company_info': {}
        }
        data_result
        data_result = parsing_data(data_result, r)
        df = pd.DataFrame(data_result)
        addr = df.loc['company_address']['company_info']
    df = df.transpose()   
    if len(data_result['company_info']) == 0:
        data_result = None
    with open('company_reviews.json', 'w', encoding='utf-8') as f:
        json.dump(data_result, f, ensure_ascii=False, indent=4)
    print(i,' ',time_object,' ',yandex_id,' ',url,' - Parsing Success')
    df['key'] = 1
    df['url'] = url
    df = ya.merge(df, on = 'key', indicator=True)
    estimates_all = pd.concat([estimates_all,df])
    time.sleep(7+i)
# Out:
# 0   07:09:54   59452068765   https://yandex.ru/maps/org/letay/59452068765  - Parsing Success
# 1   07:10:01   1230403863   https://yandex.ru/maps/org/letay/1230403863  - Parsing Success
# 2   07:10:10   135157708122   https://yandex.ru/maps/org/letay/135157708122  - Parsing Success
# 3   07:10:19   13084226257   https://yandex.ru/maps/org/letay/13084226257  - Parsing Success
# 4   07:10:30   122953255163   https://yandex.ru/maps/org/letay/122953255163  - Parsing Success
# 5   07:10:41   1166206684   https://yandex.ru/maps/org/letay/1166206684  - Parsing Success
# 6   07:10:54   1170778562   https://yandex.ru/maps/org/letay/1170778562  - Parsing Success
# 7   07:11:07   1080903330   https://yandex.ru/maps/org/letay/1080903330  - Parsing Success
# 8   07:11:22   1315558370   https://yandex.ru/maps/org/letay/1315558370  - Parsing Success
# 9   07:11:37   1168675286   https://yandex.ru/maps/org/letay/1168675286  - Parsing Success
# 10   07:11:54   1036543306   https://yandex.ru/maps/org/letay/1036543306  - Parsing Success
# 11   07:12:11   5651209305   https://yandex.ru/maps/org/letay/5651209305  - Parsing Success
# 12   07:12:30   66697421636   https://yandex.ru/maps/org/letay/66697421636  - Parsing Success
# 13   07:12:50   1199923913   https://yandex.ru/maps/org/letay/1199923913  - Parsing Success
# 14   07:13:10   1146856379   https://yandex.ru/maps/org/letay/1146856379  - Parsing Success
# 15   07:13:32   1752726383   https://yandex.ru/maps/org/letay/1752726383  - Parsing Success
# 16   07:13:54   68938452823   https://yandex.ru/maps/org/letay/68938452823  - Parsing Success
# 17   07:14:18   1136669337   https://yandex.ru/maps/org/letay/1136669337  - Parsing Success
# 18   07:14:42   48923682156   https://yandex.ru/maps/org/letay/48923682156  - Parsing Success
# 19   07:15:07   1084785161   https://yandex.ru/maps/org/letay/1084785161  - Parsing Success
# 20   07:15:34   106396488794   https://yandex.ru/maps/org/letay/106396488794  - Parsing Success
# 21   07:16:01   1169237983   https://yandex.ru/maps/org/letay/1169237983  - Parsing Success
# 22   07:16:30   1171367346   https://yandex.ru/maps/org/letay/1171367346  - Parsing Success
# 23   07:16:59   1226210503   https://yandex.ru/maps/org/letay/1226210503  - Parsing Success
# 24   07:17:30   244588988530   https://yandex.ru/maps/org/letay/244588988530  - Parsing Success
# 25   07:18:01   1249340350   https://yandex.ru/maps/org/letay/1249340350  - Parsing Success
# 26   07:18:34   1109319679   https://yandex.ru/maps/org/letay/1109319679  - Parsing Success
# 27   07:19:07   129281957669   https://yandex.ru/maps/org/letay/129281957669  - Parsing Success
# 28   07:19:41   222501363394   https://yandex.ru/maps/org/letay/222501363394  - Parsing Success
# 29   07:20:17   95798602015   https://yandex.ru/maps/org/letay/95798602015  - Parsing Success
# 30   07:20:53   1808210910   https://yandex.ru/maps/org/letay/1808210910  - Parsing Success
# 31   07:21:31   74755559887   https://yandex.ru/maps/org/letay/74755559887  - Parsing Success
# 32   07:22:09   39505328349   https://yandex.ru/maps/org/letay/39505328349  - Parsing Success
# 33   07:22:48   58618253938   https://yandex.ru/maps/org/letay/58618253938  - Parsing Success
# 34   07:23:29   181349390806   https://yandex.ru/maps/org/letay/181349390806  - Parsing Success
# 35   07:24:10   222108751806   https://yandex.ru/maps/org/letay/222108751806  - Parsing Success
# 36   07:24:53   1004521162   https://yandex.ru/maps/org/letay/1004521162  - Parsing Success
# 37   07:25:36   238385424377   https://yandex.ru/maps/org/letay/238385424377  - Parsing Success
# 38   07:26:21   1178994977   https://yandex.ru/maps/org/letay/1178994977  - Parsing Success
# 39   07:27:06   1809097327   https://yandex.ru/maps/org/letay/1809097327  - Parsing Success
# 40   07:27:53   225447574680   https://yandex.ru/maps/org/letay/225447574680  - Parsing Success
# 41   07:28:40   1200427674   https://yandex.ru/maps/org/letay/1200427674  - Parsing Success
# 42   07:29:28   1142895335   https://yandex.ru/maps/org/letay/1142895335  - Parsing Success
# 43   07:30:18   46866695409   https://yandex.ru/maps/org/letay/46866695409  - Parsing Success
# 44   07:31:08   1261132791   https://yandex.ru/maps/org/letay/1261132791  - Parsing Success
# 45   07:32:00   1780139580   https://yandex.ru/maps/org/letay/1780139580  - Parsing Success
# 46   07:32:52   227594122810   https://yandex.ru/maps/org/letay/227594122810  - Parsing Success
# 47   07:33:45   57361398610   https://yandex.ru/maps/org/letay/57361398610  - Parsing Success
# 48   07:34:40   1360515342   https://yandex.ru/maps/org/letay/1360515342  - Parsing Success
# 49   07:35:35   1187228400   https://yandex.ru/maps/org/letay/1187228400  - Parsing Success
# 50   07:36:32   205284667443   https://yandex.ru/maps/org/letay/205284667443  - Parsing Success
# 51   07:37:29   175499965097   https://yandex.ru/maps/org/letay/175499965097  - Parsing Success
# 07:38:28  New query for  1234696811
# 52   07:38:28   1234696811   https://yandex.ru/maps/org/letay/1234696811  - Parsing Success
# 53   07:44:27   1219578186   https://yandex.ru/maps/org/letay/1219578186  - Parsing Success
# 54   07:45:28   1243520916   https://yandex.ru/maps/org/letay/1243520916  - Parsing Success
# 55   07:46:29   1137893690   https://yandex.ru/maps/org/letay/1137893690  - Parsing Success
# 07:47:32  New query for  1163323346
# 07:52:32  New query for  1163323346
# 07:57:32  New query for  1163323346
# 08:02:32  New query for  1163323346
# 08:07:32  New query for  1163323346
# 08:12:32  New query for  1163323346
# 08:17:33  New query for  1163323346
# 08:22:33  New query for  1163323346
# 56   07:47:32   1163323346   https://yandex.ru/maps/org/letay/1163323346  - Parsing Success
# 57   08:28:36   1395617057   https://yandex.ru/maps/org/letay/1395617057  - Parsing Success
# 58   08:29:41   1156420979   https://yandex.ru/maps/org/letay/1156420979  - Parsing Success
# 59   08:30:46   1261357675   https://yandex.ru/maps/org/letay/1261357675  - Parsing Success
# 60   08:31:52   1137049971   https://yandex.ru/maps/org/letay/1137049971  - Parsing Success
# 61   08:33:00   1503884741   https://yandex.ru/maps/org/letay/1503884741  - Parsing Success
# 62   08:34:08   147075068049   https://yandex.ru/maps/org/letay/147075068049  - Parsing Success
# 63   08:35:18   1173855410   https://yandex.ru/maps/org/letay/1173855410  - Parsing Success
# 64   08:36:28   1209203365   https://yandex.ru/maps/org/letay/1209203365  - Parsing Success
# 65   08:37:40   1084635139   https://yandex.ru/maps/org/letay/1084635139  - Parsing Success
# 66   08:38:52   1357472078   https://yandex.ru/maps/org/letay/1357472078  - Parsing Success
# 08:40:06  New query for  111881168077
# 08:45:06  New query for  111881168077
# 67   08:40:06   111881168077   https://yandex.ru/maps/org/letay/111881168077  - Parsing Success
# 68   08:51:20   1737906159   https://yandex.ru/maps/org/letay/1737906159  - Parsing Success
# 69   08:52:36   1159394297   https://yandex.ru/maps/org/letay/1159394297  - Parsing Success
# 70   08:53:52   1216178581   https://yandex.ru/maps/org/letay/1216178581  - Parsing Success
# 08:55:10  New query for  1092610521
# 71   08:55:10   1092610521   https://yandex.ru/maps/org/letay/1092610521  - Parsing Success
# 72   09:01:28   1218514905   https://yandex.ru/maps/org/letay/1218514905  - Parsing Success

# %%
estimates_all
# Out:
#           date      time            id  key  \
# 0   02.11.2022  07:09:54   59452068765    1
# 0   02.11.2022  07:10:01    1230403863    1
# 0   02.11.2022  07:10:10  135157708122    1
# 0   02.11.2022  07:10:19   13084226257    1
# 0   02.11.2022  07:10:30  122953255163    1
# ..         ...       ...           ...  ...
# 0   02.11.2022  08:51:20    1737906159    1
# 0   02.11.2022  08:52:36    1159394297    1
# 0   02.11.2022  08:53:52    1216178581    1
# 0   02.11.2022  08:55:10    1092610521    1
# 0   02.11.2022  09:01:28    1218514905    1
#
#                                       company_address company_count_reviews  \
# 0   Республика Татарстан, Заинск, Казанская улица,...                  None
# 0   Республика Татарстан, Альметьевск, улица Маяко...            343 оценки
# 0   Республика Татарстан, Нижнекамск, улица Баки У...            111 оценок
# 0      Республика Татарстан, Мамадыш, улица Тукая, 32                  None
# 0   Республика Татарстан, посёлок городского типа ...                  None
# ..                                                ...                   ...
# 0   Республика Татарстан, Верхнеуслонский район, И...             41 оценка
# 0   Республика Татарстан, посёлок городского типа ...             80 оценок
# 0   Республика Татарстан, Буинск, улица Розы Люксе...            127 оценок
# 0   Республика Татарстан, Зеленодольск, улица Карл...            200 оценок
# 0   Республика Татарстан, Кайбицкий район, село Бо...             23 оценки
#
#    company_count_stars company_rating  \
# 0                 None           None
# 0                  3.5     Рейтинг3,3
# 0                  1.5     Рейтинг1,6
# 0                 None           None
# 0                 None           None
# ..                 ...            ...
# 0                    4     Рейтинг3,9
# 0                    4     Рейтинг4,0
# 0                  4.5     Рейтинг4,3
# 0                    3     Рейтинг2,8
# 0                  4.5     Рейтинг4,3
#
#                                               url _merge
# 0    https://yandex.ru/maps/org/letay/59452068765   both
# 0     https://yandex.ru/maps/org/letay/1230403863   both
# 0   https://yandex.ru/maps/org/letay/135157708122   both
# 0    https://yandex.ru/maps/org/letay/13084226257   both
# 0   https://yandex.ru/maps/org/letay/122953255163   both
# ..                                            ...    ...
# 0     https://yandex.ru/maps/org/letay/1737906159   both
# 0     https://yandex.ru/maps/org/letay/1159394297   both
# 0     https://yandex.ru/maps/org/letay/1216178581   both
# 0     https://yandex.ru/maps/org/letay/1092610521   both
# 0     https://yandex.ru/maps/org/letay/1218514905   both
#
# [73 rows x 10 columns]

# %%
day = time.strftime("%d%m%Y_%H%M")

# %%
estimates_all.to_excel('D:\\estimates\estimates_all_'+day+'.xlsx',index = False)
